# %%
#
#todo 1 - CRIAR CONFIGS, UTILS E ETC
#todo 2 - Funções
#todo 3 - Pesquisar se possui variações no link do ml "/variations" e caso possua, capturar o nome da variação para incluir no tiny
#todo 4 - Ver no tiny, como incluo uma variação

# %%
from configs import *
from utils import *
import requests

# %% [markdown]
# ### PROCESSAMENTO DE DADOS MERCADO LIVRE
# #### 1. CAPTURA OS DADOS ATRAVÉS DO CÓDIGO MLB E COLA NA PLANILHA

# %%
spreadsheet_id = '1zFD5WBSPweRnUVaPZbXTvJFDL8fR0pLfJrqZyKXK7Ro'

# %%
#! Autenticação Google Sheets

sheets_client = authenticate_gsheets(service_account_json , sheets_scopes)
sheets_client
# Out:
# A função authenticate_gsheets foi chamada!

# %%
#! Capturando dados do projeto
sheet_configs  = sheets_client.open_by_key(spreadsheet_id)
wks_busca_info  = sheet_configs.worksheet_by_title(title="Buscador de Informações")

# %%
lista_anuncios = get_active_products(wks_busca_info)
lista_anuncios
# Out:
# Executando a função get_active_products
# Função get_active_products executada com sucesso!
# ['MLB4460004412',
#  'MLB3603155495',
#  'MLB4460032318',
#  'MLB4460020794',
#  'MLB4460062780',
#  'MLB4460072520',
#  'MLB4459987658',
#  'MLB4460023168']

# %%
search_result = get_ml_data(lista_anuncios)

# %%
paste_values(wks_busca_info, search_result)

# %%
df_produtos_final_step1 = get_products_df(wks_busca_info)
df_produtos_final_step1.head()
# Out:
#   CÓDIGO Produto                                             Título    Preço  \
# 0  MLB4460004412  Churrasqueira Ninja 4 Em 1 Defumadora Fritadei...  10499.9
# 1  MLB3603155495  Fritadeira E Grill 2 Em 1 Ninja Importada - 82...   7199.9
# 2  MLB4460032318  Fritadeira Air Fryer Ninja Gigante - Assa, Gre...   4989.9
# 3  MLB4460020794  Ombrelone Lateral Importado 250x290 Cm - Venez...   2549.9
# 4  MLB4460062780  Ombrelone Central Importado 270x285 Cm Barcelo...   3869.9
#
#               Marca                                          Descrição  \
# 0             Ninja  Churrasqueira e Defumador Ninja OG850 Woodfire...
# 1             Ninja  NINJA FOODI SMART XL GRILL: Grill e Fritadeira...
# 2             Ninja  NINJA FOODI SMART XL GRILL: Grill Inteligente ...
# 3  Nattural Imports  Desfrute de momentos relaxantes sob a sombra f...
# 4  Nattural Imports  Transforme seu jardim em um refugio de eleganc...
#
#   Categoria ML Gtin / EAN                                           Url Capa  \
# 0     MLB48730        N/A  http://http2.mlstatic.com/D_939663-MLA74527450...
# 1     MLB31683        N/A  http://http2.mlstatic.com/D_688236-MLB74652748...
# 2    MLB456045        N/A  http://http2.mlstatic.com/D_641164-MLB74652729...
# 3    MLB189855        N/A  http://http2.mlstatic.com/D_770624-MLB74527528...
# 4    MLB189855        N/A  http://http2.mlstatic.com/D_689184-MLB74653396...
#
#   Dimensões Url capa                                               Url2  ...  \
# 0       Ok - 500x482  http://http2.mlstatic.com/D_638876-MLB74652234...  ...
# 1       Ok - 500x309  http://http2.mlstatic.com/D_630501-MLB74652936...  ...
# 2       Ok - 500x308  http://http2.mlstatic.com/D_872510-MLB74527192...  ...
# 3       Ok - 500x388  http://http2.mlstatic.com/D_601723-MLB74527528...  ...
# 4       Ok - 500x337  http://http2.mlstatic.com/D_701211-MLB74653198...  ...
#
#   Dimensões Url3                                               Url4  \
# 0   Ok - 500x500  http://http2.mlstatic.com/D_875962-MLB74527287...
# 1   Ok - 500x500  http://http2.mlstatic.com/D_628899-MLB74527565...
# 2   Ok - 500x500  http://http2.mlstatic.com/D_746068-MLB74652463...
# 3   Ok - 500x500  http://http2.mlstatic.com/D_998076-MLB74527528...
# 4   Ok - 500x468  http://http2.mlstatic.com/D_946182-MLB74652992...
#
#   Dimensões Url4 Tem Variação                          Variações  \
# 0   Ok - 500x500          Sim  Cor:Preto e Prata;Voltagem:Bivolt
# 1   Ok - 500x500          Sim     Cor:Preto e prata;Voltagem:110
# 2   Ok - 500x500          Sim     Cor:Preto e Prata;Voltagem:110
# 3   Ok - 500x500          Sim      Cor:Bege;Nome do desenho:Liso
# 4   Ok - 500x315          Sim      Cor:Bege;Nome do desenho:Liso
#
#               Dimensões Altura Largura  Comprimento  Peso
# 0   56x50x40 cm - 17 kg     56      50           40  17.0
# 1   40x42x28 cm - 10 kg     40      42           28  10.0
# 2   28x40x42 cm - 11 kg     28      40           42  11.0
# 3  20x20x20 cm - 0,5 kg     20      20           20   0.5
# 4  20x20x20 cm - 0,5 kg     20      20           20   0.5
#
# [5 rows x 22 columns]

# %%
categorias = get_df_categories()

# %%
df_categorias = mapeamento_categoria(df_produtos_final_step1,categorias)
df_categorias
# Out:
#   CÓDIGO Produto                                             Título    Preço  \
# 0  MLB4460004412  Churrasqueira Ninja 4 Em 1 Defumadora Fritadei...  10499.9
# 1  MLB3603155495  Fritadeira E Grill 2 Em 1 Ninja Importada - 82...   7199.9
# 2  MLB4460032318  Fritadeira Air Fryer Ninja Gigante - Assa, Gre...   4989.9
# 3  MLB4460020794  Ombrelone Lateral Importado 250x290 Cm - Venez...   2549.9
# 4  MLB4460062780  Ombrelone Central Importado 270x285 Cm Barcelo...   3869.9
# 5  MLB4460072520  Ombrelone Lateral Importado 240x290 Cm - Viena...   2099.9
# 6  MLB4459987658  Ombrelone Central Importado 230x260 Cm - Paris...   1349.9
# 7  MLB4460023168  Ombrelone Lateral Importado 265x285 Cm - Londr...   3869.9
#
#               Marca                                          Descrição  \
# 0             Ninja  Churrasqueira e Defumador Ninja OG850 Woodfire...
# 1             Ninja  NINJA FOODI SMART XL GRILL: Grill e Fritadeira...
# 2             Ninja  NINJA FOODI SMART XL GRILL: Grill Inteligente ...
# 3  Nattural Imports  Desfrute de momentos relaxantes sob a sombra f...
# 4  Nattural Imports  Transforme seu jardim em um refugio de eleganc...
# 5  Nattural Imports  Desfrute de momentos ao ar livre com conforto ...
# 6  Nattural Imports  Desfrute seu jardim protegido do sol com elega...
# 7  Nattural Imports  Aproveite seus dias ao ar livre com estilo e p...
#
#                                         Categoria ML Gtin / EAN  \
# 0  Eletrodomésticos >> Pequenos Eletrodomésticos ...        N/A
# 1  Eletrodomésticos >> Pequenos Eletrodomésticos ...        N/A
# 2  Eletrodomésticos >> Pequenos Eletrodomésticos ...        N/A
# 3  Casa, Móveis e Decoração >> Jardim e Ar Livre ...        N/A
# 4  Casa, Móveis e Decoração >> Jardim e Ar Livre ...        N/A
# 5  Casa, Móveis e Decoração >> Jardim e Ar Livre ...        N/A
# 6  Casa, Móveis e Decoração >> Jardim e Ar Livre ...        N/A
# 7  Casa, Móveis e Decoração >> Jardim e Ar Livre ...        N/A
#
#                                             Url Capa Dimensões Url capa  \
# 0  http://http2.mlstatic.com/D_939663-MLA74527450...       Ok - 500x482
# 1  http://http2.mlstatic.com/D_688236-MLB74652748...       Ok - 500x309
# 2  http://http2.mlstatic.com/D_641164-MLB74652729...       Ok - 500x308
# 3  http://http2.mlstatic.com/D_770624-MLB74527528...       Ok - 500x388
# 4  http://http2.mlstatic.com/D_689184-MLB74653396...       Ok - 500x337
# 5  http://http2.mlstatic.com/D_781528-MLB74527323...       Ok - 500x412
# 6  http://http2.mlstatic.com/D_685990-MLB74527531...       Ok - 500x385
# 7  http://http2.mlstatic.com/D_615393-MLB74527964...       Ok - 500x370
#
#                                                 Url2  ... Dimensões Url4  \
# 0  http://http2.mlstatic.com/D_638876-MLB74652234...  ...   Ok - 500x500
# 1  http://http2.mlstatic.com/D_630501-MLB74652936...  ...   Ok - 500x500
# 2  http://http2.mlstatic.com/D_872510-MLB74527192...  ...   Ok - 500x500
# 3  http://http2.mlstatic.com/D_601723-MLB74527528...  ...   Ok - 500x500
# 4  http://http2.mlstatic.com/D_701211-MLB74653198...  ...   Ok - 500x315
# 5  http://http2.mlstatic.com/D_626074-MLB74653225...  ...   Ok - 500x413
# 6  http://http2.mlstatic.com/D_657869-MLB74527530...  ...   Ok - 500x493
# 7  http://http2.mlstatic.com/D_649598-MLB74653395...  ...   Ok - 469x500
#
#   Tem Variação                          Variações             Dimensões  \
# 0          Sim  Cor:Preto e Prata;Voltagem:Bivolt   56x50x40 cm - 17 kg
# 1          Sim     Cor:Preto e prata;Voltagem:110   40x42x28 cm - 10 kg
# 2          Sim     Cor:Preto e Prata;Voltagem:110   28x40x42 cm - 11 kg
# 3          Sim      Cor:Bege;Nome do desenho:Liso  20x20x20 cm - 0,5 kg
# 4          Sim      Cor:Bege;Nome do desenho:Liso  20x20x20 cm - 0,5 kg
# 5          Sim    Cor:Branco;Nome do desenho:Liso  20x20x20 cm - 0,5 kg
# 6          Sim     Cor:Cinza;Nome do desenho:Liso  20x20x20 cm - 0,5 kg
# 7          Sim    Cor:Branco;Nome do desenho:Liso  20x20x20 cm - 0,5 kg
#
#   Altura Largura Comprimento  Peso      Categoria Final Tiny  \
# 0     56      50          40  17.0  Churrasqueiras Elétricas
# 1     40      42          28  10.0             Sanduicheiras
# 2     28      40          42  11.0                     De Ar
# 3     20      20          20   0.5               Guarda-Sóis
# 4     20      20          20   0.5               Guarda-Sóis
# 5     20      20          20   0.5               Guarda-Sóis
# 6     20      20          20   0.5               Guarda-Sóis
# 7     20      20          20   0.5               Guarda-Sóis
#
#                                            Categoria
# 0  Eletrodomésticos >> Pequenos Eletrodomésticos ...
# 1  Eletrodomésticos >> Pequenos Eletrodomésticos ...
# 2  Eletrodomésticos >> Pequenos Eletrodomésticos ...
# 3  Casa, Móveis e Decoração >> Jardim e Ar Livre ...
# 4  Casa, Móveis e Decoração >> Jardim e Ar Livre ...
# 5  Casa, Móveis e Decoração >> Jardim e Ar Livre ...
# 6  Casa, Móveis e Decoração >> Jardim e Ar Livre ...
# 7  Casa, Móveis e Decoração >> Jardim e Ar Livre ...
#
# [8 rows x 24 columns]

# %% [markdown]
# ### INTEGRANDO TINY COM OS DADOS DO ML NA PLANILHA
# #### 1. CAPTURA OS DADOS DA PLANILHA, SUBSTITUI PELOS DADOS NECESSÁRIO NO TINY E CRIA O JSON

# %%
# Cria o JSON com base nos dados do DataFrame
produto_info = criar_json_produtos(df_categorias)
produto_info
# Visualiza o JSON gerado
#print(json.dumps(produtos_info, indent=4))
# Out:
# {'produtos': [{'produto': {'sequencia': 1,
#     'nome': 'Churrasqueira Ninja 4 Em 1 Defumadora Fritadeira E Assadeira',
#     'codigo': 'MLB4460004412',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 10499.9,
#     'peso_liquido': 17.0,
#     'peso_bruto': 17.0,
#     'altura_embalagem': 56.0,
#     'largura_embalagem': 50.0,
#     'comprimento_embalagem': 40.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 'Eletrodomésticos >> Pequenos Eletrodomésticos >> Para a Cozinha >> Preparação de Alimentos >> Churrasqueiras Elétricas',
#     'descricao_complementar': 'Churrasqueira e Defumador Ninja OG850 Woodfire Pro XL ao Ar Livre com Termometro Integrado, Churrasqueira 4 em 1, Defumador de Churrasco, Fritadeira a Ar ao Ar Livre, Assadeira, Portatil, Eletrica, Azul\n\nA Ninja apresenta a revolucionaria Churrasqueira e Defumador OG850 Woodfire Pro XL, a solucao definitiva para churrasco e defumacao ao ar livre, agora em um unico aparelho!\n\nPrincipais Caracteristicas:\n\nMarca: Ninja\nModelo: Ninja OG850\nCor: Azul\nPeso do Item: 17,66 Kg\nDimensoes do Produto: 56,6 cm de diametro x 50,9 cm de largura x 40,2 cm de altura\nMaterial Interno: Aco inoxidavel\nTipo de Combustivel: Lenha\nFuncionalidade 4 em 1:\n\nChurrasqueira, Defumador de Churrasco, Fritadeira a Ar e Assadeira, com sabores 100% autenticos de lenha, tudo em um so lugar.\nCapacidade para Entretenimento:\n\nEspaco de cozimento de 1161 cm2, 30% maior do que a churrasqueira ao ar livre Ninja original, que comporta ate 2 racks completos de costelas, 10 hamburgueres, 1,8 kg de asas de frango, 2 frangos de 3,2 kg cada ou 4,5 kg de peito bovino.\nTermometro Integrado:\n\nMonitora o progresso dos alimentos e alerta quando estiverem prontos, para que voce possa aproveitar o churrasco enquanto a comida cozinha a perfeicao.\n\nChurrasco de Mestre:\n\nObtenha todo o desempenho de uma churrasqueira a gas de tamanho normal com o mesmo sabor de churrasco e selagem.\nDefumador de Churrasco a Prova de Bobagens:\n\nCrie casca e sabor de churrasco autenticos de forma rapida e facil com apenas 1/2 xicara de pellets.\nFritadeira a Ar ao Ar Livre:\n\nAdicione o sabor da lenha aos seus favoritos fritos a ar e prepare todos os seus acompanhamentos ao ar livre.\nTecnologia de Lenha:\n\nAlimentado por eletricidade, com sabor de pellets de madeira queimada real. Crie um sabor rico em lenha que voce pode ver e provar com qualquer funcao de cozimento.\nResistente as Intemperies:\n\nConstruido para resistir aos elementos, pode ser utilizado e armazenado ao ar livre durante todo o ano.\nChurrasqueira de Qualquer Lugar:\n\nDe varandas de apartamentos pequenos a trailers, decks, quintais ou ate mesmo festas no estacionamento, voce pode grelhar de quase qualquer lugar.\nO que esta incluido:\n\nGrade de grelha antiaderente de 1161 cm2, termometro embutido, cesta crocante, bandeja de gordura e forro descartavel para bandeja de gordura, colher de pellets, pacotes iniciantes de pellets Ninja Woodfire Robust & All-Purpose Blend.\n\nNao perca a chance de dominar a arte do churrasco e defumacao com a Churrasqueira e Defumador Ninja OG850 Woodfire Pro XL!',
#     'marca': 'Ninja',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_939663-MLA74527450166_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_638876-MLB74652234023_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_833009-MLB74652934761_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_875962-MLB74527287500_022024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB4460004412-1',
#        'preco': '10499.9',
#        'estoque_atual': 100,
#        'grade': {'Cor': 'Preto e Prata', 'Voltagem': 'Bivolt'}}}]}},
#   {'produto': {'sequencia': 2,
#     'nome': 'Fritadeira E Grill 2 Em 1 Ninja Importada - 825w - Aco Inox',
#     'codigo': 'MLB3603155495',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 7199.9,
#     'peso_liquido': 10.0,
#     'peso_bruto': 10.0,
#     'altura_embalagem': 40.0,
#     'largura_embalagem': 42.0,
#     'comprimento_embalagem': 28.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 'Eletrodomésticos >> Pequenos Eletrodomésticos >> Para a Cozinha >> Preparação de Alimentos >> Sanduicheiras',
#     'descricao_complementar': 'NINJA FOODI SMART XL GRILL: Grill e Fritadeira de Ar Inteligente 6 em 1 com Termometro Inteligente, Preto/Prata\n\nA Ninja apresenta o revolucionario Ninja Foodi Smart XL Grill, o grill inteligente que grelha, sela e deixa sua comida crocante. Este grill de bancada indoor e tambem uma fritadeira a ar com o Sistema de Cozimento Inteligente e Termometro Integrado.\n\nPrincipais Caracteristicas:\n\nMarca: Ninja\nModelo: FG551\nCor: Preto e Prata\nPeso do Item: 10,16 Kg\nDimensoes do Produto: 40 cm de diametro x 42 cm de largura x 28,2 cm de altura\nMaterial: Aco Inoxidavel\nPotencia: 825 watts\nTecnologia de Grelhados Ciclonicos:\n\nUtiliza ar ciclonico a 260degC para cozinhar ou grelhar perfeitamente sua comida ao seu ponto desejado na grelha para deliciosas marcas e sabores grelhados.\nSistema de Cozimento Inteligente mais Termometro:\n\nO Termometro Foodi Smart permite que voce alcance o ponto de cozimento perfeito, de mal passado a bem passado, com 4 configuracoes inteligentes de proteina e 9 niveis de cozimento personalizaveis. Faca tudo isso com um toque de botao, sem mais adivinhacoes ou comida que fica crua ou passada demais.\nCapacidade XL:\n\nA grelha suporta ate 6 bifes, ate 24 cachorros-quentes, pratos principais e acompanhamentos ao mesmo tempo, e muito mais.\n6 Funcoes de Cozimento:\n\nGrelhar, Air Crisp, Assar, Assar, Grelhar e Desidratar habilitados pela ampla faixa de temperatura.\nAte 75% menos gordura:\n\nFrite com ar ate 75% menos gordura do que fritura profunda (testado contra batatas fritas fritas a mao), usando a cesta crocante de 4 qt incluida.\nSistema de Controle de Fumaca:\n\nA combinacao das praticas recomendadas de grelhados pelo chef, uma grelha controlada por temperatura, protecao contra respingos e zona de ar frio reduz a fumaca, mantendo-a fora da cozinha.\nEsqueca o Descongelamento:\n\nTransforme alimentos congelados em grelhados perfeitamente grelhados em menos de 25 minutos.\nTermometro Inteligente Foodi de Sensor Duplo:\n\nMonitora continuamente a temperatura em dois lugares para resultados ainda mais precisos.\nO que esta incluido:\n\nNinja Foodi Smart XL Grill, Grade de Grelha de Alta Densidade de 9" x 12" com Revestimento Antiaderente, Cesta Crocante de 4 qt com Revestimento Ceramico Livre de PTFE/PFOA, Panela de Cozimento de 4 qt com Revestimento Ceramico Livre de PTFE/PFOA, Escova de Limpeza, Livro de Receitas com 15 Receitas Criadas pelo Chef.\n\nDomine a arte do grelhado e fritura com o Ninja Foodi Smart XL Grill e transforme suas refeicoes em verdadeiras experiencias gourmet!',
#     'marca': 'Ninja',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_688236-MLB74652748339_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_630501-MLB74652936187_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_600727-MLB74527190940_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_628899-MLB74527565480_022024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB3603155495-1',
#        'preco': '7199.9',
#        'estoque_atual': 100,
#        'grade': {'Cor': 'Preto e prata', 'Voltagem': '110'}}}]}},
#   {'produto': {'sequencia': 3,
#     'nome': 'Fritadeira Air Fryer Ninja Gigante - Assa, Grelha, Cozinha',
#     'codigo': 'MLB4460032318',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 4989.9,
#     'peso_liquido': 11.0,
#     'peso_bruto': 11.0,
#     'altura_embalagem': 28.0,
#     'largura_embalagem': 40.0,
#     'comprimento_embalagem': 42.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 'Eletrodomésticos >> Pequenos Eletrodomésticos >> Para a Cozinha >> Preparação de Alimentos >> Fritadeiras >> De Ar',
#     'descricao_complementar': 'NINJA FOODI SMART XL GRILL: Grill Inteligente XL 6 em 1 com Air Fry, Assar, Grelhar, Cozer e Desidratar, Termometro Inteligente, Preto/Prata\n\nConheca o Ninja Foodi Smart XL Grill, o grill inteligente XL que grelha, sela e deixa sua comida crocante. Este grill de bancada indoor e tambem uma fritadeira a ar com o Sistema de Cozimento Inteligente e Termometro Integrado.\n\nPrincipais Caracteristicas:\n\nMarca: Ninja\nModelo: DG551\nCor: Preto e Prata\nPeso do Item: 11,34 Kg\nDimensoes do Produto: 28,2 cm de diametro x 40 cm de largura x 42 cm de altura\nMaterial: Ceramica\nPotencia: 825 watts\nSistema de Cozimento Inteligente e Termometro:\n\nO Termometro Foodi Smart permite que voce alcance o ponto de cozimento perfeito, de mal passado a bem passado, com 4 configuracoes inteligentes de proteina e 9 niveis de cozimento personalizaveis. Faca tudo isso com um toque de botao, sem mais adivinhacoes ou comida que fica crua ou passada demais.\nTecnologia de Grelhados Ciclonicos:\n\nUtiliza ar ciclonico a 260degC e grelha a 260degC para cozinhar ou grelhar perfeitamente sua comida com marcas grelhadas e sabores deliciosos.\nCapacidade XL para Familia:\n\nA grelha suporta ate 6 bifes, ate 24 cachorros-quentes, pratos principais e acompanhamentos ao mesmo tempo, e muito mais.\n6 Funcoes de Cozimento Versateis:\n\nGrelhar, Air Crisp, Assar, Assar, Grelhar e Desidratar habilitados pela ampla faixa de temperatura.\nAte 75% Menos Gordura:\n\nFrite com ar ate 75% menos gordura do que fritura profunda (testado contra batatas fritas fritas a mao), usando a cesta crocante de 4 qt incluida.\nSistema de Controle de Fumaca:\n\nA combinacao das praticas recomendadas de grelhados pelo chef, uma grelha controlada por temperatura, protecao contra respingos e zona de ar frio reduz a fumaca, mantendo-a fora da cozinha.\nEsqueca o Descongelamento:\n\nTransforme alimentos congelados em grelhados perfeitamente grelhados em menos de 25 minutos.\nFacil de Limpar:\n\nA grelha, cesta crocante e panela de cozimento revestidas de ceramica removiveis sao todas seguras para lava-loucas, faceis de limpar e livres de PTFE/PFOA.\nO que esta incluido:\n\nNinja Foodi Smart XL Grill, Grade de Grelha de Alta Densidade de 9" x 12", Cesta Crocante de 4 qt, Panela de Cozimento de 4 qt, Termometro Foodi Smart, Escova de Limpeza e Livro de Receitas com 15 Receitas Criadas pelo Chef.\n\nTransforme suas refeicoes com o Ninja Foodi Smart XL Grill e desfrute de pratos deliciosos e saudaveis em familia!',
#     'marca': 'Ninja',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_641164-MLB74652729925_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_872510-MLB74527192244_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_867208-MLB74527290348_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_746068-MLB74652463629_022024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB4460032318-1',
#        'preco': '4989.9',
#        'estoque_atual': 100,
#        'grade': {'Cor': 'Preto e Prata', 'Voltagem': '110'}}}]}},
#   {'produto': {'sequencia': 4,
#     'nome': 'Ombrelone Lateral Importado 250x290 Cm - Veneza - Bege',
#     'codigo': 'MLB4460020794',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 2549.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 'Casa, Móveis e Decoração >> Jardim e Ar Livre >> Móveis para Jardim >> Tendas Gazebo e Pergolados >> Guarda-Sóis',
#     'descricao_complementar': 'Desfrute de momentos relaxantes sob a sombra fresca do Ombrelone 2,5x2,9m Lateral Aluminio Bege, da Nattural Imports. Este elegante acessorio nao so oferece protecao contra os raios solares prejudiciais, com seu fator de protecao solar de 30 UV, mas tambem adiciona um toque de charme ao seu espaco ao ar livre.\n\nPrincipais Caracteristicas:\n\nMarca: Nattural Imports\nModelo: Veneza\nTipo de Ombrelone: Lateral\nMaterial da Estrutura: Metal (Aluminio e Aco)\nMaterial da Cobertura: Tecido em Poliester\nDimensoes: 2,50 m de altura x 2,90 m de largura x 2,90 m de diametro\nPeso: 15,00 Kg\nProtecao UV: Sim, fator 30 UV\nMontagem: Desmontado, com complexidade media\nDesign Elegante e Funcional:\nCom sua tonalidade bege e formato hexagonal, este ombrelone combina perfeitamente com qualquer estilo de decoracao, proporcionando um ambiente convidativo e acolhedor em seu jardim ou area de lazer. Sua estrutura lateral permite uma instalacao versatil, podendo ser colocada em bases especificas ou em mesas com furo para ombrelone, garantindo praticidade e conforto.\n\nResistencia e Durabilidade:\nFabricado com materiais de alta qualidade, este ombrelone oferece nao apenas protecao solar eficaz, mas tambem resistencia a condicoes climaticas adversas. Sua construcao robusta e acabamento cuidadoso garantem anos de uso sem preocupacoes.\n\nCuidados Simples, Garantia Longa:\n\nPara manter seu ombrelone em otimas condicoes, basta seguir algumas orientacoes simples de limpeza e armazenamento. A garantia de 24 meses oferecida pelo fabricante cobre eventuais defeitos de fabricacao, proporcionando tranquilidade e seguranca ao seu investimento.\n\nAdquira ja o Ombrelone 2,5x2,9m Lateral Aluminio Bege Veneza e desfrute de momentos agradaveis e protegidos em seu espaco exterior!',
#     'marca': 'Nattural Imports',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_770624-MLB74527528656_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_601723-MLB74527528646_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_615082-MLB74527627866_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_998076-MLB74527528664_022024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB4460020794-1',
#        'preco': '2549.9',
#        'estoque_atual': 100,
#        'grade': {'Cor': 'Bege', 'Nome do desenho': 'Liso'}}}]}},
#   {'produto': {'sequencia': 5,
#     'nome': 'Ombrelone Central Importado 270x285 Cm Barcelona - Bege',
#     'codigo': 'MLB4460062780',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 3869.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 'Casa, Móveis e Decoração >> Jardim e Ar Livre >> Móveis para Jardim >> Tendas Gazebo e Pergolados >> Guarda-Sóis',
#     'descricao_complementar': 'Transforme seu jardim em um refugio de elegancia e conforto com o Ombrelone Barcelona, da Nattural Imports. Com sua estrutura central em aluminio e cobertura em poliester, este ombrelone e o complemento perfeito para seu espaco ao ar livre.\n\nDesfrute de momentos de lazer protegido dos raios solares, pois a cobertura filtra 100% dos raios UV. Alem disso, a durabilidade e garantida pela estrutura resistente ao tempo, sendo ideal para uso em areas externas.\n\nCom a manivela integrada, abrir e fechar o ombrelone se torna uma tarefa simples e sem esforco. E para iluminar suas noites ao ar livre, o ombrelone possui luzes de LED alimentadas por energia solar, proporcionando um ambiente aconchegante e convidativo.\n\nCaracteristicas principais:\n\nTipo de Ombrelone: Central\nMaterial da Estrutura: Aluminio\nMaterial da Cobertura: Poliester\nDimensoes: 2,70 m de altura, 2,85 m de largura, 2,85 m de comprimento\nProtecao UV: Sim, com fator de protecao solar de 50 UV\nPeso do Produto: 8,00 Kg\nGarantia: 36 meses para a estrutura, 24 meses para a cobertura\nCom o Ombrelone Barcelona, seu jardim ganha um toque de estilo e sofisticacao, proporcionando momentos agradaveis em qualquer hora do dia. Aproveite cada momento ao ar livre com conforto e elegancia!\n\nAtencao: A base do ombrelone deve ser adquirida separadamente. Em caso de chuvas fortes e ventanias, recolha o ombrelone e armazene em local seguro.',
#     'marca': 'Nattural Imports',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_689184-MLB74653396379_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_701211-MLB74653198597_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_980958-MLB74653188651_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_946182-MLB74652992807_022024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB4460062780-1',
#        'preco': '3869.9',
#        'estoque_atual': 100,
#        'grade': {'Cor': 'Bege', 'Nome do desenho': 'Liso'}}}]}},
#   {'produto': {'sequencia': 6,
#     'nome': 'Ombrelone Lateral Importado 240x290 Cm - Viena - Branco',
#     'codigo': 'MLB4460072520',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 2099.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 'Casa, Móveis e Decoração >> Jardim e Ar Livre >> Móveis para Jardim >> Tendas Gazebo e Pergolados >> Guarda-Sóis',
#     'descricao_complementar': 'Desfrute de momentos ao ar livre com conforto e elegancia com o Ombrelone Lateral Hexa Polar Branco, da Nattural Imports. Seu design hexagonal em aco oferece resistencia e durabilidade, enquanto sua cor branca proporciona um toque de sofisticacao ao ambiente externo.\n\nPrincipais Caracteristicas:\n\nMarca: Nattural Imports\nModelo: Viena\nTipo de Ombrelone: Lateral\nMaterial da Estrutura: Aco\nMaterial da Cobertura: Tecido em Poliester\nCor: Branco\nProtecao UV: Sim, filtro solar de 95%\nDimensao: 2,40 m de altura x 2,90 m de largura x 2,90 m de diametro\nPeso: 11,00 Kg\nMontagem: Desmontado, com complexidade media\nProtecao Contra os Raios Solares:\nCom sua cobertura em poliester, o Ombrelone Polar filtra 95% dos raios solares, proporcionando um ambiente mais fresco e protegido para voce aproveitar seu jardim ou area de lazer sem preocupacoes com danos causados pelo sol.\n\nDesign Funcional e Pratico:\nEquipado com uma manivela, o Ombrelone Polar facilita a abertura e o fechamento, tornando a instalacao e o armazenamento muito mais simples e conveniente. Sua estrutura lateral hexagonal oferece uma cobertura ampla, ideal para combinar com mesas, cadeiras ou ate mesmo uma espreguicadeira para completar seu espaco externo.\n\nDurabilidade e Conforto:\nAlem de proteger contra os raios solares, este ombrelone e construido com materiais de alta qualidade, garantindo resistencia e durabilidade ao longo do tempo. Sua cor branca confere um visual elegante e atemporal, combinando perfeitamente com qualquer estilo de decoracao.\n\nDicas de Manutencao e Garantia:\nPara prolongar a vida util do produto, e importante realizar a montagem conforme as instrucoes fornecidas pelo fabricante. Em caso de sujeira, basta limpar com agua e sabao neutro. A garantia oferecida pela Nattural Imports cobre danos de fabricacao e tem duracao de 24 meses.\n\nAproveite o conforto e a protecao oferecidos pelo Ombrelone Lateral Hexa Polar Branco e desfrute de momentos relaxantes ao ar livre!',
#     'marca': 'Nattural Imports',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_781528-MLB74527323624_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_626074-MLB74653225159_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_866699-MLB74652989799_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_680290-MLB74527599470_022024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB4460072520-1',
#        'preco': '2099.9',
#        'estoque_atual': 100,
#        'grade': {'Cor': 'Branco', 'Nome do desenho': 'Liso'}}}]}},
#   {'produto': {'sequencia': 7,
#     'nome': 'Ombrelone Central Importado 230x260 Cm - Paris - Branco',
#     'codigo': 'MLB4459987658',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 1349.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 'Casa, Móveis e Decoração >> Jardim e Ar Livre >> Móveis para Jardim >> Tendas Gazebo e Pergolados >> Guarda-Sóis',
#     'descricao_complementar': 'Desfrute seu jardim protegido do sol com elegancia e estilo! O Ombrelone Paris, da Nattural Imports, e uma escolha sofisticada para o seu espaco exterior. Com design central em formato hexagonal e estrutura de aco, oferece durabilidade e resistencia superiores.\n\nA cobertura em poliester filtra ate 90% dos raios solares, garantindo conforto e protecao contra os efeitos nocivos do sol. Alem disso, e facilmente removivel para limpeza e substituicao, prolongando a vida util do produto.\n\nEquipado com uma manivela, o Ombrelone Paris permite uma abertura e fechamento suaves, facilitando a instalacao e o armazenamento. Seu tamanho compacto e peso leve tornam-no ideal para diversos espacos ao ar livre, desde jardins ate areas de piscina.\n\nNao se esqueca de adquirir a base compativel para uma estabilidade ainda maior.\n\nPrincipais caracteristicas:\n\nModelo: Ombrelone Central\nMaterial da Estrutura: Aco\nMaterial da Cobertura: Poliester\nDimensoes: 2,30 m de altura, 2,60 m de largura, 2,60 m de diametro\nProtecao UV: Sim, com fator de protecao solar de 12 UV\nManivela para abertura e fechamento facil\nResistente e facil de usar',
#     'marca': 'Nattural Imports',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_685990-MLB74527531000_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_657869-MLB74527530898_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_798161-MLB74527324436_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_743592-MLB74653226087_022024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB4459987658-1',
#        'preco': '1349.9',
#        'estoque_atual': 100,
#        'grade': {'Cor': 'Cinza', 'Nome do desenho': 'Liso'}}}]}},
#   {'produto': {'sequencia': 8,
#     'nome': 'Ombrelone Lateral Importado 265x285 Cm - Londres - Branco',
#     'codigo': 'MLB4460023168',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 3869.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 'Casa, Móveis e Decoração >> Jardim e Ar Livre >> Móveis para Jardim >> Tendas Gazebo e Pergolados >> Guarda-Sóis',
#     'descricao_complementar': 'Aproveite seus dias ao ar livre com estilo e protecao! O Ombrelone Londres, da Nattural Imports, e perfeito para o seu jardim ou area de piscina, oferecendo elegancia e funcionalidade em um so produto.\n\nCom sua estrutura em aluminio, o Ombrelone Londres e resistente a corrosao, garantindo durabilidade mesmo em ambientes umidos. Seu design lateral em formato quadrado proporciona uma ampla area de sombra, ideal para relaxar e curtir momentos agradaveis ao ar livre.\n\nA cobertura em poliester filtra 100% dos raios UV, protegendo voce e sua familia dos danos causados pelo sol. Alem disso, sua manivela permite abrir e fechar o ombrelone com facilidade, proporcionando praticidade no uso diario.\n\nCom a possibilidade de remover a cobertura para limpeza ou substituicao, o Ombrelone Londres e projetado para durar, garantindo conforto e protecao por muito tempo.\n\nNao perca a chance de complementar seu espaco exterior com beleza e funcionalidade. Confira tambem nossos conjuntos de moveis para jardim e deixe seu ambiente ainda mais completo!\n\nPrincipais caracteristicas:\n\nModelo: Ombrelone Lateral\nMaterial da Estrutura: Aluminio e Aco\nMaterial da Cobertura: Poliester\nDimensoes: 2,65 m de altura, 2,85 m de largura, 2,85 m de diametro\nProtecao UV: Sim, com fator de protecao solar de 50 UV\nArticulavel, com inclinacao frontal e giro de 360o\nEquipado com pedal e manivela para facil uso\nPeso do Produto: 26,00 Kg\nBeneficios: Durabilidade, Protecao UV, Facil de usar',
#     'marca': 'Nattural Imports',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_615393-MLB74527964820_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_649598-MLB74653395315_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_810631-MLB74527611318_022024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_902000-MLB74652784551_022024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB4460023168-1',
#        'preco': '3869.9',
#        'estoque_atual': 100,
#        'grade': {'Cor': 'Branco', 'Nome do desenho': 'Liso'}}}]}}]}

# %%
#
#! Conectando ao tiny e criando os produtos
connect_and_create_tiny(produto_info)
# Out:
# Erro na solicitação. Código de erro: 3
# [{'registro': {'variacoes': [{'variacao': {'id': 815287626}}], 'sequencia': '1', 'status': 'OK', 'id': 815287625}}, {'registro': {'variacoes': [{'variacao': {'id': 815287635}}], 'sequencia': '2', 'status': 'OK', 'id': 815287634}}, {'registro': {'variacoes': [{'variacao': {'id': 815287642}}], 'sequencia': '3', 'status': 'OK', 'id': 815287641}}, {'registro': {'variacoes': [{'variacao': {'id': 815287649}}], 'sequencia': '4', 'status': 'OK', 'id': 815287648}}, {'registro': {'variacoes': [{'variacao': {'id': 815287657}}], 'sequencia': '5', 'status': 'OK', 'id': 815287656}}, {'registro': {'variacoes': [{'variacao': {'id': 815287664}}], 'sequencia': '6', 'status': 'OK', 'id': 815287663}}, {'registro': {'variacoes': [{'variacao': {'id': 815287671}}], 'sequencia': '7', 'status': 'OK', 'id': 815287670}}, {'registro': {'variacoes': [{'variacao': {'id': 815287679}}], 'sequencia': '8', 'status': 'OK', 'id': 815287678}}]
