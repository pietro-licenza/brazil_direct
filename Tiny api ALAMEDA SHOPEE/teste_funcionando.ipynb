# %%
#
#todo 1 - CRIAR CONFIGS, UTILS E ETC
#todo 2 - Funções
#todo 3 - Pesquisar se possui variações no link do ml "/variations" e caso possua, capturar o nome da variação para incluir no tiny
#todo 4 - Ver no tiny, como incluo uma variação

# %%
from configs import *
from utils import *
import requests
import os
from io import BytesIO

# %% [markdown]
# ### PROCESSAMENTO DE DADOS MERCADO LIVRE
# #### 1. CAPTURA OS DADOS ATRAVÉS DO CÓDIGO MLB E COLA NA PLANILHA

# %%
spreadsheet_id = '1zFD5WBSPweRnUVaPZbXTvJFDL8fR0pLfJrqZyKXK7Ro'

# %%
#! Autenticação Google Sheets

sheets_client = authenticate_gsheets(service_account_json , sheets_scopes)
sheets_client
# Out:
# A função authenticate_gsheets foi chamada!

# %%
#! Capturando dados do projeto
sheet_configs  = sheets_client.open_by_key(spreadsheet_id)
wks_busca_info  = sheet_configs.worksheet_by_title(title="Buscador de Informações")

# %%
lista_anuncios = get_active_products(wks_busca_info)
lista_anuncios
# Out:
# Executando a função get_active_products
# Função get_active_products executada com sucesso!
# ['MLB5092989086',
#  'MLB5092950832',
#  'MLB5092951526',
#  'MLB3864945243',
#  'MLB5092978350',
#  'MLB5093017064',
#  'MLB5093005204',
#  'MLB3864947199',
#  'MLB5092992902',
#  'MLB5092942106']

# %%
search_result = get_ml_data(lista_anuncios)

# %%
paste_values(wks_busca_info, search_result)

# %%
df_produtos_final_step1 = get_products_df(wks_busca_info)
df_produtos_final_step1.head()
# Out:
#   CÓDIGO Produto                                             Título   Preço  \
# 0  MLB5092989086  Conjunto Varanda 5 Pecas Eucalipto Preto - Mes...  8497.9
# 1  MLB5092950832  Conjunto De Jardim 5 Pecas Compass Cinza - Mes...  7497.9
# 2  MLB5092951526  Conjunto De Jardim 5 Pecas Modena Marrom - Mes...  6697.9
# 3  MLB3864945243  Conjunto Jardim 5 Pecas Cinza Cadeira Mesa Omb...  5697.9
# 4  MLB5092978350  Conjunto Jardim 7 Pecas Rattan - Mesa E 6 Banc...  6997.9
#
#       Marca                                          Descrição Categoria ML  \
# 0  Naterial  Transforme seu espaco externo em um ambiente e...    MLB436394
# 1  Naterial  Transforme seu ambiente externo com o Conjunto...    MLB436394
# 2  Naterial  Adicione um toque de sofisticacao e funcionali...    MLB436394
# 3  Naterial  Transforme sua area externa em um espaco elega...    MLB436394
# 4  Naterial  De um toque sofisticado e elegante ao seu espa...    MLB436394
#
#   Gtin / EAN                                           Url Capa  \
# 0        N/A  http://http2.mlstatic.com/D_997692-MLB79424669...
# 1        N/A  http://http2.mlstatic.com/D_909717-MLB79424554...
# 2        N/A  http://http2.mlstatic.com/D_758363-MLB79669532...
# 3        N/A  http://http2.mlstatic.com/D_975852-MLB79425038...
# 4        N/A  http://http2.mlstatic.com/D_782694-MLB79670184...
#
#                           Dimensões Url capa  \
# 0  Imagem fora do Padrão - Tamanho - 500x232
# 1                               Ok - 500x281
# 2  Imagem fora do Padrão - Tamanho - 500x232
# 3                               Ok - 491x500
# 4                               Ok - 500x373
#
#                                                 Url2  ... Dimensões Url3  \
# 0  http://http2.mlstatic.com/D_920444-MLB79669333...  ...   Ok - 335x500
# 1  http://http2.mlstatic.com/D_767211-MLB79425035...  ...   Ok - 500x500
# 2  http://http2.mlstatic.com/D_987572-MLB79424948...  ...   Ok - 500x442
# 3  http://http2.mlstatic.com/D_915783-MLB79669709...  ...   Ok - 485x500
# 4  http://http2.mlstatic.com/D_747351-MLB79424891...  ...   Ok - 500x367
#
#                                                 Url4  \
# 0  http://http2.mlstatic.com/D_604695-MLB79669615...
# 1  http://http2.mlstatic.com/D_711269-MLB79669394...
# 2  http://http2.mlstatic.com/D_622021-MLB79669532...
# 3  http://http2.mlstatic.com/D_714248-MLB79669837...
# 4  http://http2.mlstatic.com/D_861673-MLB79424891...
#
#                               Dimensões Url4 Tem Variação  \
# 0                               Ok - 355x500          Sim
# 1  Imagem fora do Padrão - Tamanho - 500x205          Sim
# 2                               Ok - 335x500          Sim
# 3                               Ok - 500x448          Sim
# 4                               Ok - 500x356          Sim
#
#                  Variações             Dimensões Altura Largura  Comprimento  \
# 0   Cor da estrutura:Preto  20x20x20 cm - 0,5 kg     20      20           20
# 1   Cor da estrutura:Cinza  20x20x20 cm - 0,5 kg     20      20           20
# 2  Cor da estrutura:Marrom  20x20x20 cm - 0,5 kg     20      20           20
# 3   Cor da estrutura:Cinza  20x20x20 cm - 0,5 kg     20      20           20
# 4  Cor da estrutura:Rattan  20x20x20 cm - 0,5 kg     20      20           20
#
#    Peso
# 0   0.5
# 1   0.5
# 2   0.5
# 3   0.5
# 4   0.5
#
# [5 rows x 22 columns]

# %%
categorias = get_df_categories()

# %%
df_categorias = mapeamento_categoria(df_produtos_final_step1,categorias)
df_categorias
# Out:
#   CÓDIGO Produto                                             Título   Preço  \
# 0  MLB5092989086  Conjunto Varanda 5 Pecas Eucalipto Preto - Mes...  8497.9
# 1  MLB5092950832  Conjunto De Jardim 5 Pecas Compass Cinza - Mes...  7497.9
# 2  MLB5092951526  Conjunto De Jardim 5 Pecas Modena Marrom - Mes...  6697.9
# 3  MLB3864945243  Conjunto Jardim 5 Pecas Cinza Cadeira Mesa Omb...  5697.9
# 4  MLB5092978350  Conjunto Jardim 7 Pecas Rattan - Mesa E 6 Banc...  6997.9
# 5  MLB5093017064  Conjunto De Jardim 5 Pecas Cinza - Mesa E 4 Ca...  3197.9
# 6  MLB5093005204  Conjunto De Jardim 5 Pecas Cinza Claro - Mesa ...  4397.9
# 7  MLB3864947199  Conjunto De Jardim 4 Pecas Cinza Premium - Mes...  7797.9
# 8  MLB5092992902  Conjunto Varanda 5 Pecas Eucalipto Preto - Mes...  7497.9
# 9  MLB5092942106  Balanco Para Jardim 1 Lugar 190cm Aco Cinza Ov...  7197.9
#
#       Marca                                          Descrição  \
# 0  Naterial  Transforme seu espaco externo em um ambiente e...
# 1  Naterial  Transforme seu ambiente externo com o Conjunto...
# 2  Naterial  Adicione um toque de sofisticacao e funcionali...
# 3  Naterial  Transforme sua area externa em um espaco elega...
# 4  Naterial  De um toque sofisticado e elegante ao seu espa...
# 5  Naterial  Transforme sua area externa em um ambiente mod...
# 6  Naterial  De um toque contemporaneo e funcional ao seu e...
# 7  Naterial  Transforme seu jardim em um espaco de conforto...
# 8  Naterial  Transforme seu espaco externo com o Conjunto p...
# 9  Naterial  Adicione um toque de sofisticacao e modernidad...
#
#                                         Categoria ML Gtin / EAN  \
# 0                                                  0        N/A
# 1                                                  0        N/A
# 2                                                  0        N/A
# 3                                                  0        N/A
# 4                                                  0        N/A
# 5                                                  0        N/A
# 6                                                  0        N/A
# 7                                                  0        N/A
# 8                                                  0        N/A
# 9  Casa, Móveis e Decoração >> Jardim e Ar Livre ...        N/A
#
#                                             Url Capa  \
# 0  http://http2.mlstatic.com/D_997692-MLB79424669...
# 1  http://http2.mlstatic.com/D_909717-MLB79424554...
# 2  http://http2.mlstatic.com/D_758363-MLB79669532...
# 3  http://http2.mlstatic.com/D_975852-MLB79425038...
# 4  http://http2.mlstatic.com/D_782694-MLB79670184...
# 5  http://http2.mlstatic.com/D_622100-MLB79424943...
# 6  http://http2.mlstatic.com/D_944480-MLB79425615...
# 7  http://http2.mlstatic.com/D_923614-MLB79669883...
# 8  http://http2.mlstatic.com/D_654939-MLB79670190...
# 9  http://http2.mlstatic.com/D_932524-MLB79425787...
#
#                           Dimensões Url capa  \
# 0  Imagem fora do Padrão - Tamanho - 500x232
# 1                               Ok - 500x281
# 2  Imagem fora do Padrão - Tamanho - 500x232
# 3                               Ok - 491x500
# 4                               Ok - 500x373
# 5                               Ok - 500x378
# 6                               Ok - 500x370
# 7  Imagem fora do Padrão - Tamanho - 500x205
# 8                               Ok - 500x330
# 9                               Ok - 320x500
#
#                                                 Url2  ...  \
# 0  http://http2.mlstatic.com/D_920444-MLB79669333...  ...
# 1  http://http2.mlstatic.com/D_767211-MLB79425035...  ...
# 2  http://http2.mlstatic.com/D_987572-MLB79424948...  ...
# 3  http://http2.mlstatic.com/D_915783-MLB79669709...  ...
# 4  http://http2.mlstatic.com/D_747351-MLB79424891...  ...
# 5  http://http2.mlstatic.com/D_972655-MLB79424894...  ...
# 6  http://http2.mlstatic.com/D_668262-MLB79670405...  ...
# 7  http://http2.mlstatic.com/D_600569-MLB79425617...  ...
# 8  http://http2.mlstatic.com/D_696736-MLB79425470...  ...
# 9  http://http2.mlstatic.com/D_947084-MLB79425787...  ...
#
#                               Dimensões Url4 Tem Variação  \
# 0                               Ok - 355x500          Sim
# 1  Imagem fora do Padrão - Tamanho - 500x205          Sim
# 2                               Ok - 335x500          Sim
# 3                               Ok - 500x448          Sim
# 4                               Ok - 500x356          Sim
# 5                               Ok - 500x381          Sim
# 6                               Ok - 336x500          Sim
# 7  Imagem fora do Padrão - Tamanho - 500x209          Sim
# 8                               Ok - 294x500          Sim
# 9                               Ok - 263x500          Sim
#
#                         Variações             Dimensões Altura Largura  \
# 0          Cor da estrutura:Preto  20x20x20 cm - 0,5 kg     20      20
# 1          Cor da estrutura:Cinza  20x20x20 cm - 0,5 kg     20      20
# 2         Cor da estrutura:Marrom  20x20x20 cm - 0,5 kg     20      20
# 3          Cor da estrutura:Cinza  20x20x20 cm - 0,5 kg     20      20
# 4         Cor da estrutura:Rattan  20x20x20 cm - 0,5 kg     20      20
# 5          Cor da estrutura:Cinza  20x20x20 cm - 0,5 kg     20      20
# 6    Cor da estrutura:Cinza claro  20x20x20 cm - 0,5 kg     20      20
# 7    Cor da estrutura:Cinza claro  20x20x20 cm - 0,5 kg     20      20
# 8          Cor da estrutura:Preto  20x20x20 cm - 0,5 kg     20      20
# 9  Cor:Preto;Nome do desenho:Oval  20x20x20 cm - 0,5 kg     20      20
#
#   Comprimento Peso  Categoria Final Tiny  \
# 0          20  0.5                   NaN
# 1          20  0.5                   NaN
# 2          20  0.5                   NaN
# 3          20  0.5                   NaN
# 4          20  0.5                   NaN
# 5          20  0.5                   NaN
# 6          20  0.5                   NaN
# 7          20  0.5                   NaN
# 8          20  0.5                   NaN
# 9          20  0.5  Cadeiras para Jardim
#
#                                            Categoria
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Casa, Móveis e Decoração >> Jardim e Ar Livre ...
#
# [10 rows x 24 columns]

# %%
import os
import requests
from PIL import Image
from io import BytesIO
import pandas as pd

# Função para converter números em letras
def number_to_letter(number):
    if number <= 9:
        return str(number)
    else:
        # Converte números maiores que 9 para letras
        return chr(65 + (number - 10))

# Supondo que o DataFrame já esteja disponível
df = df_produtos_final_step1

# Defina o caminho para a pasta de downloads
download_path = os.path.join(os.path.expanduser('~'), 'Downloads')

# Função para baixar e redimensionar a imagem
def download_and_resize_image(url, file_name):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            image = Image.open(BytesIO(response.content))
            # Redimensiona a imagem para 500x500 usando o filtro LANCZOS
            image = image.resize((500, 500), Image.LANCZOS)
            image.save(file_name)
            print(f"Imagem salva e redimensionada: {file_name}")
        else:
            print(f"Erro ao baixar {url}: Status {response.status_code}")
    except Exception as e:
        print(f"Erro ao processar {url}: {e}")

# Itere sobre o DataFrame e faça o download e redimensionamento das imagens
for index, row in df.iterrows():
    base_name = number_to_letter(index + 1)  # Nome baseado no número da linha convertido em letra

    urls = [row['Url Capa'], row.get('Url2'), row.get('Url3'), row.get('Url4')]

    for i, url in enumerate(urls, start=1):
        if pd.notna(url):  # Verifica se a URL não está vazia
            # Nome do arquivo baseado no número da linha repetido conforme o índice da coluna
            file_name = os.path.join(download_path, base_name + number_to_letter(i) + '.jpg')
            download_and_resize_image(url, file_name)
# Out:
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\11.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\12.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\13.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\14.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\21.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\22.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\23.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\24.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\31.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\32.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\33.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\34.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\41.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\42.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\43.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\44.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\51.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\52.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\53.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\54.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\61.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\62.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\63.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\64.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\71.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\72.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\73.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\74.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\81.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\82.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\83.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\84.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\91.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\92.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\93.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\94.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\A1.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\A2.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\A3.jpg
# Imagem salva e redimensionada: C:\Users\Usuário\Downloads\A4.jpg

# %% [markdown]
# ### INTEGRANDO TINY COM OS DADOS DO ML NA PLANILHA
# #### 1. CAPTURA OS DADOS DA PLANILHA, SUBSTITUI PELOS DADOS NECESSÁRIO NO TINY E CRIA O JSON

# %%
# Cria o JSON com base nos dados do DataFrame
produto_info = criar_json_produtos(df_categorias)
produto_info
# Visualiza o JSON gerado
#print(json.dumps(produtos_info, indent=4))
# Out:
# {'produtos': [{'produto': {'sequencia': 1,
#     'nome': 'Conjunto Varanda 5 Pecas Eucalipto Preto - Mesa E 4 Cadeiras',
#     'codigo': 'MLB5092989086',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 8497.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 0,
#     'descricao_complementar': 'Transforme seu espaco externo em um ambiente elegante e confortavel com o Conjunto para Jardim Mesa com 4 Cadeiras Reclinaveis Oris Naterial. Este conjunto foi projetado para proporcionar momentos de lazer e descontracao ao ar livre, unindo design moderno e funcionalidade.\n\nA mesa retangular, com estrutura em aluminio resistente e tampo em madeira eucalipto certificada FSC, garante durabilidade e um toque de sofisticacao natural. As cadeiras reclinaveis oferecem maximo conforto, com estrutura de aluminio que nao enferruja e assentos em textilene, um material que resiste as intemperies e e facil de limpar.\n\nAlem disso, as cadeiras sao dobraveis, facilitando o armazenamento e transporte, e possuem bracos revestidos com madeira eucalipto, complementando o visual elegante do conjunto.\n\nIdeal para areas externas como jardins e varandas, este conjunto e perfeito para refeicoes ao ar livre, acomodando ate 4 pessoas com conforto. O selo FSC garante que os materiais de madeira utilizados sao provenientes de manejo florestal sustentavel, proporcionando uma escolha consciente e ecologicamente correta. Com este conjunto, voce tera nao apenas um espaco funcional, mas tambem uma peca de destaque em seu jardim.\n\nCaracteristicas principais:\n\nDimensoes da mesa: 74,6 cm (altura) x 89,3 cm (largura) x 150 cm (comprimento)\nDimensoes da cadeira: 110 cm (altura) x 67 cm (largura) x 67 cm (profundidade)\nMaterial da mesa: Estrutura em aluminio e tampo em madeira eucalipto certificada FSC\nMaterial das cadeiras: Estrutura em aluminio, assento e encosto em textilene\nCapacidade de peso da cadeira: Ate 160 kg\nCadeiras dobraveis e reclinaveis\nCor: Preto\nIdeal para areas externas sem cobertura\nGarantia do fabricante: 3 anos (para defeitos de fabricacao)\n\nEste e o conjunto ideal para quem busca praticidade, conforto e design sofisticado para momentos especiais ao ar livre.',
#     'marca': 'Naterial',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_997692-MLB79424669532_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_920444-MLB79669333107_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_963915-MLB79669615837_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_604695-MLB79669615849_092024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB5092989086-1',
#        'preco': '8497.9',
#        'estoque_atual': 100,
#        'grade': {'Cor da estrutura': 'Preto'}}}]}},
#   {'produto': {'sequencia': 2,
#     'nome': 'Conjunto De Jardim 5 Pecas Compass Cinza - Mesa E 4 Cadeiras',
#     'codigo': 'MLB5092950832',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 7497.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 0,
#     'descricao_complementar': 'Transforme seu ambiente externo com o Conjunto para Jardim Mesa com 4 Cadeiras Compass Naterial, uma combinacao perfeita de modernidade, conforto e durabilidade. Ideal para areas externas cobertas, este conjunto e composto por 5 pecas, incluindo uma mesa elegante com tampo de vidro e 4 poltronas resistentes. Fabricado em aco de alta qualidade com acabamento em cinza, o conjunto traz um design contemporaneo que se adapta facilmente a diferentes estilos de decoracao.\n\nA mesa possui 74 cm de altura, 110 cm de largura e 110 cm de comprimento, oferecendo um espaco confortavel para refeicoes e momentos de lazer ao ar livre. As poltronas, por sua vez, medem 84 cm de altura, 52 cm de largura e 55 cm de profundidade, proporcionando o suporte ideal para voce e seus convidados. Alem de resistente a umidade, o conjunto e duravel e facil de limpar, garantindo longevidade e otimo custo-beneficio.\n\nCom um design neutro e sofisticado, o Conjunto Compass e perfeito para quem busca um toque de elegancia e praticidade no jardim ou varanda, sem abrir mao do conforto.\n\nCaracteristicas principais:\n\nDimensoes da mesa: 74 cm (altura) x 110 cm (largura) x 110 cm (comprimento)\nDimensoes das poltronas: 84 cm (altura) x 52 cm (largura) x 55 cm (profundidade)\nMaterial da mesa: Estrutura em aco com tampo de vidro\nMaterial das cadeiras: Estrutura em aco com encosto de polietileno\nCor: Cinza\nPeso total: 62,60 kg\nIndicado para areas externas cobertas\nDesign contemporaneo\nGarantia do fabricante: 2 anos (para defeitos de fabricacao)\n\nEste e o conjunto ideal para quem deseja um espaco ao ar livre sofisticado e resistente, perfeito para aproveitar momentos especiais com amigos e familiares.',
#     'marca': 'Naterial',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_909717-MLB79424554620_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_767211-MLB79425035182_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_991783-MLB79424554642_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_711269-MLB79669394703_092024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB5092950832-1',
#        'preco': '7497.9',
#        'estoque_atual': 100,
#        'grade': {'Cor da estrutura': 'Cinza'}}}]}},
#   {'produto': {'sequencia': 3,
#     'nome': 'Conjunto De Jardim 5 Pecas Modena Marrom - Mesa E 4 Cadeiras',
#     'codigo': 'MLB5092951526',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 6697.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 0,
#     'descricao_complementar': 'Adicione um toque de sofisticacao e funcionalidade ao seu espaco externo com o Conjunto para Jardim Mesa com 4 Cadeiras Modena Naterial. Ideal para areas ao ar livre, este conjunto foi projetado para proporcionar conforto e praticidade, sem abrir mao do estilo. Com estrutura de aluminio resistente, tanto a mesa quanto as cadeiras suportam condicoes climaticas adversas, como exposicao prolongada ao sol e a chuva.\n\nA mesa retangular, com medidas de 74 cm de altura, 100 cm de largura e 180 cm de comprimento, acomoda confortavelmente ate 8 pessoas. O tampo de vidro oferece um visual moderno e facilita a limpeza, tornando-a perfeita para momentos de confraternizacao ao ar livre. As cadeiras, por sua vez, possuem um assento em textilene que proporciona maior conforto, alem de serem empilhaveis, o que facilita o armazenamento e economiza espaco.\n\nCom design elegante na cor marrom, este conjunto e ideal para varandas, jardins e terracos, proporcionando um ambiente agradavel para refeicoes e lazer. A serie Modena combina durabilidade e estetica, sendo a escolha perfeita para quem deseja um mobiliario duradouro e de facil manutencao.\n\nCaracteristicas principais:\n\nDimensoes da mesa: 74 cm (altura) x 100 cm (largura) x 180 cm (comprimento)\nDimensoes das cadeiras: 86 cm (altura) x 55 cm (largura) x 57 cm (profundidade)\nMaterial da mesa: Estrutura em aluminio com tampo de vidro\nMaterial das cadeiras: Estrutura em aluminio com assento e encosto de textilene\nCapacidade de lugares: Ate 4 pessoas\nCor: Marrom\nIndicado para areas externas sem cobertura\nCadeiras empilhaveis para facilitar o armazenamento\nGarantia do fabricante: 2 anos (para defeitos de fabricacao)\n\nEste e o conjunto ideal para quem busca durabilidade, estilo e conforto em um so produto, perfeito para desfrutar de momentos ao ar livre com seguranca e elegancia.',
#     'marca': 'Naterial',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_758363-MLB79669532285_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_987572-MLB79424948448_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_788148-MLB79424712736_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_622021-MLB79669532239_092024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB5092951526-1',
#        'preco': '6697.9',
#        'estoque_atual': 100,
#        'grade': {'Cor da estrutura': 'Marrom'}}}]}},
#   {'produto': {'sequencia': 4,
#     'nome': 'Conjunto Jardim 5 Pecas Cinza Cadeira Mesa Ombrelone E Banco',
#     'codigo': 'MLB3864945243',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 5697.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 0,
#     'descricao_complementar': 'Transforme sua area externa em um espaco elegante e confortavel com o Conjunto para Jardim Mesa, Cadeira, Banco e Ombrelone 4 Lugares Alma Naterial. Com um design sofisticado e resistente, este conjunto e ideal para quem deseja receber convidados ao ar livre com estilo e praticidade.\n\nO conjunto e composto por uma mesa retangular com estrutura em aco e tampo de vidro, que oferece facil limpeza e durabilidade. As cadeiras, feitas em aco com assentos e encostos de textilene acolchoado, garantem conforto e ventilacao, sendo perfeitas para longos momentos de relaxamento. O banco de dois lugares segue o mesmo padrao de conforto e resistencia, sendo ideal para areas externas. Para completar, o ombrelone hexagonal com diametro de 2,6 metros oferece protecao contra os raios solares, bloqueando ate 90% dos raios UV. Ele e repelente a agua e pode ser ajustado com facilidade por meio de uma manivela lateral.\n\nEste conjunto e ideal para areas externas cobertas, oferecendo alta resistencia a intemperies e muito conforto para suas refeicoes e momentos de lazer ao ar livre.\n\nCaracteristicas principais:\n\nDimensoes da mesa: 71 cm (altura) x 90 cm (largura) x 150 cm (comprimento)\nDimensoes da cadeira: 91 cm (altura) x 55 cm (largura) x 69 cm (profundidade)\nDimensoes do banco: 91 cm (altura) x 69 cm (largura) x 70 cm (profundidade)\nDimensoes do ombrelone: 231 cm (altura) x 260 cm (diametro)\nMaterial da mesa e cadeiras: Estrutura em aco com tampo de vidro (mesa) e assentos/encostos de textilene acolchoado (cadeiras e banco)\nMaterial do ombrelone: Tecido de poliester repelente a agua com estrutura de aco\nCor: Cinza\nCapacidade de lugares: 4 pessoas (mesa), 2 pessoas (banco)\nCadeiras e banco com assento ventilado e acolchoado\nOmbrelone com manivela para ajuste facil\nIndicado para areas externas cobertas\nGarantia do fabricante: 3 meses (para defeitos de fabricacao)\n\nEste conjunto oferece um excelente custo-beneficio, unindo durabilidade, conforto e estilo para qualquer area externa, tornando seus momentos ao ar livre ainda mais agradaveis.',
#     'marca': 'Naterial',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_975852-MLB79425038420_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_915783-MLB79669709293_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_653520-MLB79669976517_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_714248-MLB79669837763_092024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB3864945243-1',
#        'preco': '5697.9',
#        'estoque_atual': 100,
#        'grade': {'Cor da estrutura': 'Cinza'}}}]}},
#   {'produto': {'sequencia': 5,
#     'nome': 'Conjunto Jardim 7 Pecas Rattan - Mesa E 6 Bancos - Importado',
#     'codigo': 'MLB5092978350',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 6997.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 0,
#     'descricao_complementar': 'De um toque sofisticado e elegante ao seu espaco externo com o Conjunto Bar Tulum 7 Pecas Ratan Just Home Collection. Este conjunto e composto por uma mesa de bar e seis banquetas, perfeitas para criar um ambiente acolhedor e convidativo no jardim, varanda ou area gourmet. Feito em aco resistente, o conjunto e revestido em ratan sintetico na cor cafe/cinza, oferecendo nao apenas estilo, mas tambem durabilidade para suportar as intemperies do tempo.\n\nA mesa de bar e o ponto central deste conjunto, com um design moderno e funcional, ideal para momentos de confraternizacao com amigos e familiares. As seis banquetas oferecem conforto e praticidade, sendo ideais para acomodar ate seis pessoas. Com um acabamento em ratan sintetico, o conjunto combina um visual natural com a resistencia do aco, tornando-se uma excelente opcao para quem busca beleza e durabilidade.\n\nPerfeito para areas externas, este conjunto oferece tudo o que voce precisa para criar um ambiente agradavel e sofisticado para suas reunioes ao ar livre.\n\nCaracteristicas principais:\n\nCapacidade: Acomoda ate 6 pessoas\nPeso bruto e liquido: 70,5 kg\nNumero de pecas: 7 (1 mesa de bar + 6 banquetas)\nMaterial: Estrutura de aco com revestimento em ratan sintetico\nCor: Cafe/Cinza\nDimensoes da embalagem: 147 cm (comprimento) x 86 cm (largura) x 26 cm (altura)\nDobravel: Nao\nRodas: Nao\nOrigem: Importado\nGarantia: 3 meses\n\nEste conjunto e a escolha ideal para quem deseja aliar funcionalidade e design em um unico produto, transformando qualquer ambiente em um espaco sofisticado e acolhedor.',
#     'marca': 'Naterial',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_782694-MLB79670184839_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_747351-MLB79424891664_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_642204-MLB79669534205_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_861673-MLB79424891680_092024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB5092978350-1',
#        'preco': '6997.9',
#        'estoque_atual': 100,
#        'grade': {'Cor da estrutura': 'Rattan'}}}]}},
#   {'produto': {'sequencia': 6,
#     'nome': 'Conjunto De Jardim 5 Pecas Cinza - Mesa E 4 Cadeiras',
#     'codigo': 'MLB5093017064',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 3197.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 0,
#     'descricao_complementar': 'Transforme sua area externa em um ambiente moderno e funcional com o Conjunto para Jardim Mesa com 4 Cadeiras Emys Naterial. Este conjunto e ideal para areas cobertas e proporciona conforto e elegancia em qualquer ocasiao. Com uma estrutura robusta em aco e acabamento em cinza, o conjunto traz durabilidade e resistencia, sendo perfeito para espacos ao ar livre.\n\nA mesa retangular com tampo de vidro temperado oferece um visual clean e facil manutencao, enquanto as quatro cadeiras dobraveis, com assentos e encostos em textilene, garantem ventilacao e conforto para momentos de lazer. O design contemporaneo, com linhas simples e sofisticadas, adapta-se facilmente a qualquer estilo de decoracao, tornando-o ideal para refeicoes ao ar livre e momentos de descontracao.\n\nO conjunto e composto por cinco pecas, sendo uma mesa e quatro cadeiras, todas desmontaveis e faceis de armazenar. Perfeito para varandas, terracos e areas de jardim, o Conjunto Emys combina praticidade, estilo e conforto.\n\nCaracteristicas principais:\n\nDimensoes da mesa: 72 cm (altura) x 70 cm (largura) x 110 cm (comprimento)\nDimensoes das cadeiras: 84 cm (altura) x 42 cm (largura) x 48,5 cm (profundidade)\nMaterial da mesa: Estrutura em aco com tampo de vidro temperado\nMaterial das cadeiras: Estrutura em aco com assento e encosto em textilene\nCapacidade: 4 lugares\nCor: Cinza\nMesa e cadeiras dobraveis\nIndicado para areas externas cobertas\nGarantia do fabricante: 2 anos (para defeitos de fabricacao)\n\nEste conjunto e a escolha perfeita para quem deseja combinar estilo e praticidade, aproveitando o melhor de seus espacos ao ar livre com conforto e sofisticacao.',
#     'marca': 'Naterial',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_622100-MLB79424943406_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_972655-MLB79424894238_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_651198-MLB79670128427_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_870630-MLB79669762747_092024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB5093017064-1',
#        'preco': '3197.9',
#        'estoque_atual': 100,
#        'grade': {'Cor da estrutura': 'Cinza'}}}]}},
#   {'produto': {'sequencia': 7,
#     'nome': 'Conjunto De Jardim 5 Pecas Cinza Claro - Mesa E 4 Cadeiras',
#     'codigo': 'MLB5093005204',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 4397.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 0,
#     'descricao_complementar': 'De um toque contemporaneo e funcional ao seu espaco externo com o Conjunto para Jardim Mesa com 4 Cadeiras Emys Naterial, na elegante cor cinza claro. Este conjunto e ideal para areas externas cobertas, sendo perfeito para refeicoes ao ar livre e momentos de lazer. A mesa retangular possui estrutura em aco com tampo de vidro temperado, que proporciona durabilidade e um visual sofisticado. As cadeiras dobraveis sao praticas e confortaveis, com estrutura em aco e assentos/encostos de textilene, um material resistente e facil de limpar, que garante conforto e ventilacao durante o uso.\n\nCom design moderno e linhas limpas, o conjunto Emys se adapta perfeitamente a qualquer ambiente, trazendo uma atmosfera agradavel e aconchegante para seu jardim ou varanda. Alem de funcional, e pratico de guardar, pois tanto a mesa quanto as cadeiras sao dobraveis, facilitando o armazenamento e economizando espaco.\n\nCaracteristicas principais:\n\nDimensoes da mesa: 72 cm (altura) x 70 cm (largura) x 110 cm (comprimento)\nDimensoes das cadeiras: 84 cm (altura) x 42 cm (largura) x 48,5 cm (profundidade)\nMaterial da mesa: Estrutura em aco com tampo de vidro temperado\nMaterial das cadeiras: Estrutura em aco com assento e encosto em textilene\nCor: Cinza claro\nCapacidade de lugares: 4\nMesa e cadeiras dobraveis para facil armazenamento\nIndicado para areas externas cobertas\nEstilo contemporaneo\nGarantia do fabricante: 2 anos (para defeitos de fabricacao)\n\nEste conjunto e a escolha ideal para quem busca praticidade, estilo e durabilidade em um so produto, garantindo momentos agradaveis ao ar livre com sofisticacao e conforto.',
#     'marca': 'Naterial',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_944480-MLB79425615862_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_668262-MLB79670405309_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_891462-MLB79424944372_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_884441-MLB79425615892_092024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB5093005204-1',
#        'preco': '4397.9',
#        'estoque_atual': 100,
#        'grade': {'Cor da estrutura': 'Cinza claro'}}}]}},
#   {'produto': {'sequencia': 8,
#     'nome': 'Conjunto De Jardim 4 Pecas Cinza Premium - Mesa E 3 Cadeiras',
#     'codigo': 'MLB3864947199',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 7797.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 0,
#     'descricao_complementar': 'Transforme seu jardim em um espaco de conforto e relaxamento com o Conjunto para Jardim Lyra Naterial. Composto por um sofa de dois lugares, duas poltronas e uma mesa de centro, este conjunto e perfeito para momentos de lazer ao ar livre. Sua estrutura de aluminio e leve e resistente, facilitando o transporte e garantindo durabilidade, mesmo em areas externas sem cobertura. As almofadas de encosto e assento sao macias, impermeaveis e removiveis, proporcionando conforto e facilidade na manutencao.\n\nO sofa e as poltronas, alem de aconchegantes, possuem um design contemporaneo que combina com qualquer estilo de decoracao externa. A mesa de centro quadrada, com tampo de vidro, complementa o conjunto com elegancia e praticidade. Este conjunto e ideal para areas de lazer, proporcionando momentos de descanso com estilo e conforto.\n\nCaracteristicas principais:\n\nDimensoes da mesa: 29 cm (altura) x 64 cm (largura) x 64 cm (comprimento)\nDimensoes da poltrona: 55 cm (altura) x 70 cm (largura) x 66 cm (profundidade)\nDimensoes do sofa: 55 cm (altura) x 70 cm (largura) x 120 cm (profundidade)\nMaterial da estrutura: Aluminio (resistente a ferrugem)\nMaterial do tampo da mesa: Vidro\nMaterial do assento e encosto: Tecido poliester impermeavel\nCor: Cinza\nPeso total: 48 kg\nCapacidade de lugares: 4 (2 no sofa e 1 em cada poltrona)\nIndicado para areas externas sem cobertura\nGarantia do fabricante: 2 anos (para defeitos de fabricacao)\n\nCom alta durabilidade e resistencia as intemperies, o Conjunto Lyra e a escolha perfeita para quem busca conforto e sofisticacao em ambientes ao ar livre.',
#     'marca': 'Naterial',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_923614-MLB79669883321_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_600569-MLB79425617212_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_668088-MLB79669843649_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_865118-MLB79670189803_092024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB3864947199-1',
#        'preco': '7797.9',
#        'estoque_atual': 100,
#        'grade': {'Cor da estrutura': 'Cinza claro'}}}]}},
#   {'produto': {'sequencia': 9,
#     'nome': 'Conjunto Varanda 5 Pecas Eucalipto Preto - Mesa E 4 Cadeiras',
#     'codigo': 'MLB5092992902',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 7497.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 0,
#     'descricao_complementar': 'Transforme seu espaco externo com o Conjunto para Jardim Mesa com 4 Cadeiras Oris Naterial, que une conforto, praticidade e sofisticacao. Este conjunto foi pensado para trazer funcionalidade e charme para momentos ao ar livre, sendo ideal para areas externas, como jardins ou varandas. Sua estrutura em aluminio resistente a ferrugem e seu tampo em madeira de eucalipto certificada FSC garantem durabilidade e um design natural e moderno. As cadeiras oferecem conforto extra com assentos e encostos em textilene, um material ventilado, resistente as intemperies e de facil manutencao.\n\nO conjunto e composto por uma mesa retangular espacosa e quatro cadeiras, todas projetadas para oferecer ergonomia e conforto. O aluminio leve facilita o manuseio e a resistencia dos materiais assegura que o conjunto suportara o uso frequente em ambientes externos, como jardins e areas sem cobertura.\n\nApesar de o conjunto ser resistente e elegante, e importante notar que ele nao inclui ombrelone e as cadeiras nao sao dobraveis, o que pode ser uma desvantagem em espacos pequenos ou que precisem de otimizacao de espaco. No entanto, para quem busca conforto e durabilidade com um toque de sofisticacao, esse conjunto e uma escolha excelente.\n\nCaracteristicas principais:\n\nDimensoes da mesa: 74,6 cm (altura) x 89,3 cm (largura) x 150 cm (comprimento)\nDimensoes da cadeira: 84,5 cm (altura) x 55,2 cm (largura)\nMaterial da mesa: Estrutura em aluminio com tampo em madeira eucalipto certificada FSC\nMaterial das cadeiras: Estrutura em aluminio com assentos e encostos em textilene\nCapacidade: 4 lugares\nCor: Preto\nMesa e cadeiras nao dobraveis\nIndicado para areas externas sem cobertura\nGarantia do fabricante: 3 anos (para defeitos de fabricacao)\n\nEste conjunto e a combinacao perfeita entre design contemporaneo, durabilidade e funcionalidade, sendo uma otima escolha para quem deseja um espaco ao ar livre confortavel e sofisticado.',
#     'marca': 'Naterial',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_654939-MLB79670190883_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_696736-MLB79425470088_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_712681-MLB79425786406_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_736618-MLB79670131761_092024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB5092992902-1',
#        'preco': '7497.9',
#        'estoque_atual': 100,
#        'grade': {'Cor da estrutura': 'Preto'}}}]}},
#   {'produto': {'sequencia': 10,
#     'nome': 'Balanco Para Jardim 1 Lugar 190cm Aco Cinza Ovo Premium',
#     'codigo': 'MLB5092942106',
#     'gtin': 'N/A',
#     'unidade': 'UN',
#     'preco': 7197.9,
#     'peso_liquido': 0.5,
#     'peso_bruto': 0.5,
#     'altura_embalagem': 20.0,
#     'largura_embalagem': 20.0,
#     'comprimento_embalagem': 20.0,
#     'origem': '0',
#     'situacao': 'A',
#     'tipo': 'P',
#     'estoque_atual': 100,
#     'estoque_minimo': 100,
#     'dias_preparacao': 3,
#     'categoria': 'Casa, Móveis e Decoração >> Jardim e Ar Livre >> Móveis para Jardim >> Cadeiras e Bancos de Jardim >> Cadeiras para Jardim',
#     'descricao_complementar': 'Adicione um toque de sofisticacao e modernidade ao seu espaco com o Balanco para Jardim 1 Lugar 190 cm Aco Cinza Ovo Naterial. Este balanco de design oval e a peca perfeita para transformar qualquer ambiente, trazendo conforto e elegancia para suas areas externas. Fabricado em aco resistente, ele e ideal para areas cobertas e pode suportar ate 160 kg, garantindo seguranca e durabilidade por longos periodos. Alem disso, o balanco acompanha uma almofada confortavel, proporcionando um local perfeito para relaxar, ler um livro ou simplesmente aproveitar o tempo ao ar livre.\n\nCom um design contemporaneo, este balanco e uma excelente alternativa aos sofas e poltronas tradicionais, agregando personalidade e charme ao seu espaco. Suas dimensoes amplas de 190 cm de altura, 125 cm de profundidade e 100 cm de largura garantem um ambiente espacoso e acolhedor para desfrutar de momentos tranquilos. A estrutura robusta em aco e o acabamento cinza combinam com diversos estilos de decoracao, desde os mais rusticos aos mais modernos.\n\nIdeal para jardins, varandas ou areas gourmet, este balanco vai fazer com que suas conversas com amigos ou momentos de descanso se tornem ainda mais especiais. Alem disso, o produto oferece uma garantia de 36 meses contra defeitos de fabricacao, proporcionando mais tranquilidade e confianca na compra.\n\nCaracteristicas principais:\n\nDimensoes: 190 cm (altura) x 125 cm (largura) x 100 cm (profundidade)\nMaterial da estrutura: Aco resistente\nCor: Cinza\nCapacidade de peso: Ate 160 kg\nPeso do produto: 35 kg\nFormato: Oval\nAcompanha almofada\nGarantia do fabricante: 36 meses (para defeitos de fabricacao)\n\nCom este balanco oval, voce pode criar um ambiente relaxante e sofisticado, perfeito para aproveitar momentos de descanso ao ar livre com estilo e conforto.',
#     'marca': 'Naterial',
#     'garantia': '3',
#     'imagens_externas': [{'imagem_externa': {'url': 'http://http2.mlstatic.com/D_932524-MLB79425787826_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_947084-MLB79425787818_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_629328-MLB79425619718_092024-O.jpg'}},
#      {'imagem_externa': {'url': 'http://http2.mlstatic.com/D_612342-MLB79670478191_092024-O.jpg'}}],
#     'classe_produto': 'V',
#     'variacoes': [{'variacao': {'codigo': 'MLB5092942106-1',
#        'preco': '7197.9',
#        'estoque_atual': 100,
#        'grade': {'Cor': 'Preto', 'Nome do desenho': 'Oval'}}}]}}]}

# %%
#
#! Conectando ao tiny e criando os produtos
connect_and_create_tiny(produto_info)
# Out:
# Erro na solicitação. Código de erro: 2
# [{'registro': {'variacoes': [{'variacao': {'id': 823145011}}], 'sequencia': '1', 'status': 'OK', 'id': 823145010}}, {'registro': {'variacoes': [{'variacao': {'id': 823145016}}], 'sequencia': '2', 'status': 'OK', 'id': 823145015}}, {'registro': {'variacoes': [{'variacao': {'id': 823145021}}], 'sequencia': '3', 'status': 'OK', 'id': 823145020}}, {'registro': {'variacoes': [{'variacao': {'id': 823145026}}], 'sequencia': '4', 'status': 'OK', 'id': 823145025}}, {'registro': {'variacoes': [{'variacao': {'id': 823145031}}], 'sequencia': '5', 'status': 'OK', 'id': 823145030}}, {'registro': {'variacoes': [{'variacao': {'id': 823145036}}], 'sequencia': '6', 'status': 'OK', 'id': 823145035}}, {'registro': {'variacoes': [{'variacao': {'id': 823145041}}], 'sequencia': '7', 'status': 'OK', 'id': 823145040}}, {'registro': {'variacoes': [{'variacao': {'id': 823145047}}], 'sequencia': '8', 'status': 'OK', 'id': 823145046}}, {'registro': {'sequencia': '9', 'status': 'Erro', 'codigo_erro': '30', 'erros': [{'erro': 'Registro em duplicidade - nome do produto já cadastrado'}]}}, {'registro': {'variacoes': [{'variacao': {'id': 823145052}}], 'sequencia': '10', 'status': 'OK', 'id': 823145051}}]
